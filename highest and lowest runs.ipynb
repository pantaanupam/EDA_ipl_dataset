# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_matches = pd.read_csv('./ipl/matches.csv')
df_deliveries = pd.read_csv('./ipl/deliveries.csv')

# %%
df_matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df_deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
# getting match id of proper match
# i.e. excluding tie and dl applied matches

df_proper_match = df_matches[(df_matches.result == 'normal') & (df_matches.dl_applied == 0)][['id', 'season']]

# rename id to match id to merge
df_proper_match.rename(columns={"id":"match_id"}, inplace=True)

# %%
df_proper_match = pd.merge(df_proper_match, df_deliveries, how="inner", on='match_id')
df_proper_match
# Out:
#         match_id  season  inning                 batting_team  \
# 0              1    2017       1          Sunrisers Hyderabad
# 1              1    2017       1          Sunrisers Hyderabad
# 2              1    2017       1          Sunrisers Hyderabad
# 3              1    2017       1          Sunrisers Hyderabad
# 4              1    2017       1          Sunrisers Hyderabad
# ...          ...     ...     ...                          ...
# 145625       636    2016       2  Royal Challengers Bangalore
# 145626       636    2016       2  Royal Challengers Bangalore
# 145627       636    2016       2  Royal Challengers Bangalore
# 145628       636    2016       2  Royal Challengers Bangalore
# 145629       636    2016       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# ...

# %%
# remove super over matches
df_proper_match = df_proper_match[(df_proper_match.is_super_over == 0)]

df_proper_match = df_proper_match.groupby(['match_id', 'inning']).sum().sort_values(by='total_runs', ascending=True).reset_index()[['match_id', 'inning', 'total_runs']]
df_proper_match
# Out:
#       match_id  inning  total_runs
# 0           27       2          49
# 1          119       2          58
# 2           44       2          66
# 3           35       1          67
# 4           99       1          67
# ...        ...     ...         ...
# 1215       562       1         235
# 1216        61       1         240
# 1217       206       1         246
# 1218       620       1         248
# 1219       411       1         263
#
# [1220 rows x 3 columns]

# %%
df_proper_match.rename(columns={'match_id':'id'}, inplace=True)

# getting top and bottom 10 rows
lowest, highest = df_proper_match.head(10), df_proper_match.sort_values(by='total_runs', ascending=False).head(10)

# %% [markdown]
# ##### for lowest data

# %%
lowest = pd.merge(lowest, df_matches, on='id', how='inner')[['season', 'inning', 'city', 'team1', 'team2','toss_winner','toss_decision', 'total_runs']]

# %%
def score_format(df):
    scoring_team = ""
    against = ""
    if(df.toss_decision == 'field'):
        if(df.inning == 1):
            if(df.toss_winner != df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
        else:
            if(df.toss_winner == df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
    else:
        if(df.inning == 1):
            if(df.toss_winner == df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
        else:
            if(df.toss_winner != df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
    return scoring_team,against

lowest['low_scoring_team'] = lowest.apply(lambda row : score_format(row)[0], axis=1)
lowest['against'] = lowest.apply(lambda row : score_format(row)[1], axis=1)

# %%
lowest = lowest[['low_scoring_team', 'against', 'total_runs', 'season']]
lowest
# Out:
#               low_scoring_team                      against  total_runs  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders          49
# 1             Rajasthan Royals  Royal Challengers Bangalore          58
# 2             Delhi Daredevils               Mumbai Indians          66
# 3             Delhi Daredevils              Kings XI Punjab          67
# 4              Kings XI Punjab             Delhi Daredevils          68
# 5        Kolkata Knight Riders               Mumbai Indians          67
# 6               Mumbai Indians        Kolkata Knight Riders          68
# 7  Royal Challengers Bangalore             Rajasthan Royals          70
# 8             Rajasthan Royals  Royal Challengers Bangalore          71
# 9              Kings XI Punjab       Rising Pune Supergiant          73
#
#    season
# 0    2017
# 1    2009
# 2    2017
# 3    2017
# 4    2017
# 5    2008
# 6    2008
# 7    2014
# 8    2014
# 9    2017

# %% [markdown]
# ##### for highest

# %%
highest = pd.merge(highest, df_matches, on='id', how='inner')[['season', 'inning', 'city', 'team1', 'team2','toss_winner','toss_decision', 'total_runs']]

# %%
def score_format(df):
    scoring_team = ""
    against = ""
    if(df.toss_decision == 'field'):
        if(df.inning == 1):
            if(df.toss_winner != df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
        else:
            if(df.toss_winner == df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
    else:
        if(df.inning == 1):
            if(df.toss_winner == df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
        else:
            if(df.toss_winner != df.team1):
                scoring_team = df.team1
                against = df.team2
            else:
                scoring_team = df.team2
                against = df.team1
    return scoring_team,against

highest['high_scoring_team'] = highest.apply(lambda row : score_format(row)[0], axis=1)
highest['against'] = highest.apply(lambda row : score_format(row)[1], axis=1)

# %%
highest = highest[['high_scoring_team', 'against', 'total_runs', 'season']]
highest
# Out:
#              high_scoring_team                      against  total_runs  \
# 0  Royal Challengers Bangalore                Pune Warriors         263
# 1  Royal Challengers Bangalore                Gujarat Lions         248
# 2          Chennai Super Kings             Rajasthan Royals         246
# 3          Chennai Super Kings              Kings XI Punjab         240
# 4  Royal Challengers Bangalore               Mumbai Indians         235
# 5              Kings XI Punjab  Royal Challengers Bangalore         232
# 6             Delhi Daredevils              Kings XI Punjab         231
# 7              Kings XI Punjab          Chennai Super Kings         231
# 8              Kings XI Punjab               Mumbai Indians         230
# 9  Royal Challengers Bangalore          Sunrisers Hyderabad         227
#
#    season
# 0    2013
# 1    2016
# 2    2010
# 3    2008
# 4    2015
# 5    2011
# 6    2011
# 7    2014
# 8    2017
# 9    2016
