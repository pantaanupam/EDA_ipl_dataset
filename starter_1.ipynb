# %% [markdown]
# ## Task 1: Read CSV Files

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
df_matches = pd.read_csv('./ipl/matches.csv')
df_deliveries = pd.read_csv('./ipl/deliveries.csv')

# %%
df_matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ## Task 2: Get top-level summary

# %%
df_matches.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# ## Task 3: Check if column 'umpire3' is useful. If not drop it and save the dataframe to a file.

# %%
df_matches['umpire3'].unique()
df2_matches = df_matches.drop(['umpire3'], axis=1)
df2_matches.to_csv('./ipl/matches2.csv', index=False)

# %%
##Task 4: Print Total Number of Mataches played, Number of Seasons,

# %%
print("total no. of matches played =", df_matches.shape[0])
# Out:
# total no. of matches played = 636

# %%
print('Total no. of seasons =', df_matches['season'].nunique())
# Out:
# Total no. of seasons = 10

# %% [markdown]
# ## Task 5: Players who have won the most "Player of the Match"
# ## And Team which has the highest number of match wins

# %%
df_matches['player_of_match']
# Out:
# 0        Yuvraj Singh
# 1           SPD Smith
# 2             CA Lynn
# 3          GJ Maxwell
# 4           KM Jadhav
#             ...
# 631           V Kohli
# 632    AB de Villiers
# 633      MC Henriques
# 634         DA Warner
# 635       BCJ Cutting
# Name: player_of_match, Length: 636, dtype: object

# %%
print(df_matches['player_of_match'].value_counts())
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# RG Sharma         14
#                   ..
# S Nadeem           1
# RJ Harris          1
# R Ashwin           1
# DL Vettori         1
# MS Gony            1
# Name: player_of_match, Length: 201, dtype: int64

# %%
my_list = [df_matches['player_of_match'].value_counts().index[0], df_matches.player_of_match.value_counts()[0]]

print("Player with the highest 'Player Of The Match' is {} and has won {} times".format(*my_list))
# Out:
# Player with the highest 'Player Of The Match' is CH Gayle and has won 18 times

# %%
my_list = [df_matches.winner.value_counts().index[0], df_matches.winner.value_counts()[0]]

print("{} has won the most times, i.e. {} times".format(*my_list))
# Out:
# Mumbai Indians has won the most times, i.e. 92 times

# %% [markdown]
# ## Task 6: Find Teams which have won matches by a huge margin

# %%
df1 = df_matches[(df_matches.win_by_runs > 100) | (df_matches.win_by_wickets > 8)]

df1.winner.value_counts()
# Out:
# Royal Challengers Bangalore    13
# Delhi Daredevils                7
# Mumbai Indians                  6
# Kolkata Knight Riders           6
# Chennai Super Kings             5
# Rajasthan Royals                4
# Kings XI Punjab                 3
# Sunrisers Hyderabad             2
# Rising Pune Supergiants         1
# Deccan Chargers                 1
# Rising Pune Supergiant          1
# Name: winner, dtype: int64

# %% [markdown]
# ## Task 7: Find Count of Matches Played at each city

# %%
print("Matches played at each city are:\nCity \t\tGames\n",df_matches.city.value_counts())
# Out:
# Matches played at each city are:
# City 		Games
#  Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Ranchi             7
# Abu Dhabi          7
# Port Elizabeth     7
# Cape Town          7
# Cuttack            7
# Sharjah            6
# Raipur             6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# East London        3
# Kimberley          3
# Bloemfontein       2
# Name: city, dtype: int64

# %% [markdown]
# ## Task 8: Find Min and Max win_by_wickets at each city

# %%
df_matches.groupby(['city', 'winner']).apply(lambda x : x.reset_index(drop=True))
# Out:
#                                           id  season           city  \
# city          winner
# Abu Dhabi     Chennai Super Kings     0  465    2014      Abu Dhabi
#               Kings XI Punjab         0  460    2014      Abu Dhabi
#                                       1  472    2014      Abu Dhabi
#               Kolkata Knight Riders   0  458    2014      Abu Dhabi
#               Rajasthan Royals        0  461    2014      Abu Dhabi
# ...                                      ...     ...            ...
# Visakhapatnam Rising Pune Supergiants 0  625    2016  Visakhapatnam
#                                       1  629    2016  Visakhapatnam
#               Sunrisers Hyderabad     0  537    2015  Visakhapatnam
#                                       1  613    2016  Visakhapatnam
#                                       2  616    2016  Visakhapatnam
#
#                                                date                  team1  \
# city          winner
# ...

# %% [markdown]
# ## Task 9: Find the match with biggest defeat by runs,

# %%
# df_matches[df_matches.win_by_runs == df_matches.win_by_runs.max()]

df1 = df_matches.sort_values('win_by_runs',ascending=False).head(1)

df1
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2  umpire3
# 43  Nitin Menon  CK Nandan      NaN

# %%
df1['win_by_runs']
# Out:
# 43    146
# Name: win_by_runs, dtype: int64

# %% [markdown]
# ## Task 10: Find the match with biggest defeat by wickets

# %%
df_matches.sort_values('win_by_wickets', ascending=False).head()
# Out:
#       id  season        city        date             team1  \
# 183  184    2010   Bangalore  2010-03-18  Rajasthan Royals
# 298  299    2011      Mumbai  2011-05-20    Mumbai Indians
# 71    72    2008      Mumbai  2008-04-27    Mumbai Indians
# 34    35    2017  Chandigarh  2017-04-30  Delhi Daredevils
# 542  543    2015       Delhi  2015-04-26  Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 183  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 298             Rajasthan Royals               Mumbai Indians           bat
# 71               Deccan Chargers              Deccan Chargers         field
# 34               Kings XI Punjab              Kings XI Punjab         field
# 542  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#      result  dl_applied                       winner  win_by_runs  \
# 183  normal           0  Royal Challengers Bangalore            0
# ...

# %%
# match which are won by 10 wickets:
df_matches[df_matches['win_by_wickets'] == 10]
# Out:
#       id  season        city        date             team1  \
# 2      3    2017      Rajkot  2017-04-07     Gujarat Lions
# 34    35    2017  Chandigarh  2017-04-30  Delhi Daredevils
# 71    72    2008      Mumbai  2008-04-27    Mumbai Indians
# 119  120    2009   Cape Town  2009-04-19   Kings XI Punjab
# 183  184    2010   Bangalore  2010-03-18  Rajasthan Royals
# 298  299    2011      Mumbai  2011-05-20    Mumbai Indians
# 376  377    2012      Jaipur  2012-05-20  Rajasthan Royals
# 390  391    2013  Chandigarh  2013-04-10   Kings XI Punjab
# 542  543    2015       Delhi  2015-04-26  Delhi Daredevils
# 590  591    2016      Rajkot  2016-04-21     Gujarat Lions
#
#                            team2                  toss_winner toss_decision  \
# 2          Kolkata Knight Riders        Kolkata Knight Riders         field
# 34               Kings XI Punjab              Kings XI Punjab         field
# 71               Deccan Chargers              Deccan Chargers         field
# ...

# %%
df_matches.iloc[df_matches['win_by_runs'].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object
